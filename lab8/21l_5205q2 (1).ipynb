# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#reading file
data=pd.read_csv("horseRacing.csv")
#cleaning data and encoding
data.isnull().sum()
clean_data=data.dropna()
data_encoded=pd.get_dummies(clean_data, columns=['race_id', 'horse_id'])
data_encoded.head()
clean_data.corr()
#plotting
clean_data.boxplot(column="price")
Q1 = np.percentile(clean_data["price"], 25)
Q3 = np.percentile(clean_data["price"], 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_iqr = clean_data["price"][(clean_data["price"] < lower_bound) | (clean_data["price"] > upper_bound)]
